# %% [markdown]
# # Privacy-Utility Tradeoff Analysis (KFed vs. FedDP-Init)
#
# This notebook runs a series of experiments to compare the privacy-utility tradeoff for two different federated k-means initialization methods on the **Gaussian Data-Point Privacy** scenario.
#
# We will test two scenarios over a range of privacy budgets (epsilon):
#
# 1.  **Scenario 1: `initialization_algorithm: KFed` (Non-Private Init)**
#     * This uses a **non-private** initialization method (`KFed`).
#     * Privacy is **only** applied during the `FederatedLloyds` clustering steps.
#     * We will set `fedlloyds_epsilon` to our target `E` and plot against the final **printed epsilon** for the "Clustering" phase.
#
# 2.  **Scenario 2: `initialization_algorithm: FederatedClusterInitExact` (Private Init)**
#     * This uses the paper's novel **private** initialization method (`FedDP-Init`).
#     * Based on the paper's findings (Table 4), we will set **`fedlloyds_num_iterations: 0`**.
#     * We will split the total target epsilon `E` across the **three** initialization steps (`E/3` each).
#     * We will plot against the final, **printed epsilon** for the "Initialization" phase.
#
# **Metrics:**
# * **Utility (Y-axis):** K-Means Cost (lower is better) and Clustering Accuracy (higher is better).
# * **Privacy (X-axis):** Final Composed Epsilon (lower is better).

# %%
import os
import sys
import subprocess
import yaml
import re
import pickle
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- 1. Setup & Configuration ---

# Add project root to path and change CWD
PROJECT_ROOT = ".."
notebook_dir = os.path.abspath('')
project_root_path = os.path.abspath(os.path.join(notebook_dir, PROJECT_ROOT))

if project_root_path not in sys.path:
    print(f"Adding {project_root_path} to system path.")
    sys.path.insert(0, project_root_path)

if os.getcwd() != project_root_path:
    print(f"Changing CWD from {os.getcwd()} to {project_root_path}")
    os.chdir(project_root_path)
else:
    print(f"Already in correct CWD: {os.getcwd()}")

# --- Global Settings ---
BASE_CONFIG_PATH = 'configs/gaussians_data_privacy.yaml'

# --- !!! --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- ---
# --- TO RUN THE FULL SCRIPT, UNCOMMENT THE "FULL" LINE AND COMMENT THE "TEST" LINE ---
EPSILON_VALUES_TEST = [0.25, 1.0] # Quick test run (2 values)
EPSILON_VALUES_FULL = np.arange(0.25, 2.26, 0.25).tolist() # Full run [0.25, 0.5, ..., 2.25]

# EPSILON_TARGET_RANGE = EPSILON_VALUES_TEST
EPSILON_TARGET_RANGE = EPSILON_VALUES_FULL # <-- UNCOMMENT THIS LINE FOR THE FULL RUN
# --- !!! --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- ---

RESULTS_DIR = 'results/data_point_level/GaussianMixtureUniform'
RESULTS_PKL_PATH = os.path.join(RESULTS_DIR, 'summary_results.pkl')
TEMP_CONFIG_DIR = 'paper_scripts' # Save temp configs here
SEED = 42

print(f"Base Config: {BASE_CONFIG_PATH}")
print(f"Epsilon Target Range: {EPSILON_TARGET_RANGE}")
print(f"Results Path: {RESULTS_PKL_PATH}")
print(f"CWD: {os.getcwd()}")
# Out:
# Adding /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main to system path.
# Changing CWD from /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main/paper_scripts to /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main
# Base Config: configs/gaussians_data_privacy.yaml
# Epsilon Target Range: [0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0, 2.25]
# Results Path: results/data_point_level/GaussianMixtureUniform/summary_results.pkl
# CWD: /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main

# %%
# --- 2. Helper Functions (Unchanged) ---

def create_temp_config(base_config, overrides, path):
    """Creates a temporary YAML config file with specified overrides."""
    config = base_config.copy()
    config.update(overrides)
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, 'w') as f:
        yaml.dump(config, f)
    print(f"Created temp config: {path}")

def run_experiment(config_path):
    """Runs run.py with the given config (from project root) and returns stdout."""
    cmd = ['python', 'run.py', '--args_config', config_path, '--seed', str(SEED)]
    print(f"\n---> Running command: {' '.join(cmd)}")
    
    try:
        result = subprocess.run(cmd, capture_output=True, text=True, check=True, encoding='utf-8')
        print(result.stdout)
        if result.stderr:
            print("--- STDERR ---")
            print(result.stderr)
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"--- ERROR running experiment --- (returncode {e.returncode})")
        print("--- STDOUT ---")
        print(e.stdout)
        print("--- STDERR ---")
        print(e.stderr)
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

def parse_output_and_results(stdout, pkl_path):
    """
    Parses the final epsilon/delta from stdout and loads cost/accuracy from the pkl file.
    """
    final_epsilon = np.nan
    final_delta = np.nan
    cost = np.nan
    accuracy = np.nan
    
    try:
        # Pattern to find: "Clustering is (EPSILON, DELTA)-DP"
        pattern_clustering = re.compile(r"Clustering is \(([\d\.]+), ([\de\-\+]+)\)-DP")
        pattern_init = re.compile(r"Initialization is \(([\d\.]+), ([\de\-\+]+)\)-DP")
        
        matches_clustering = pattern_clustering.findall(stdout)
        matches_init = pattern_init.findall(stdout)

        if matches_clustering:
            # If Clustering ran, that's the final, composed cost
            final_epsilon = float(matches_clustering[-1][0])
            final_delta = float(matches_clustering[-1][1])
            print(f"Parsed Epsilon (from Clustering): {final_epsilon}, Parsed Delta: {final_delta}")
        elif matches_init:
            # If only Init ran (e.g., fedlloyds_num_iterations=0), that's the final cost
            final_epsilon = float(matches_init[-1][0])
            final_delta = float(matches_init[-1][1])
            print(f"Parsed Epsilon (from Init): {final_epsilon}, Parsed Delta: {final_delta}")
        else:
            print("Warning: Could not parse epsilon/delta from stdout.")
    except Exception as e:
        print(f"Error parsing epsilon/delta: {e}")

    try:
        with open(pkl_path, 'rb') as f:
            results_dict = pickle.load(f)
        
        final_key = 'Clustering' if 'Clustering' in results_dict else 'Initialization'
        if final_key in results_dict:
            cost = results_dict[final_key].get('Train client cost', np.nan)
            accuracy = results_dict[final_key].get('Train client accuracy', np.nan)
            print(f"Loaded Cost: {cost}, Accuracy: {accuracy} (from '{final_key}')")
        else:
            print(f"Warning: '{final_key}' key not in {pkl_path}.")
            
    except FileNotFoundError:
        print(f"Error: Results file not found at {pkl_path}")
    except Exception as e:
        print(f"Error loading pkl file: {e}")
        
    return final_epsilon, final_delta, cost, accuracy

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# --- 3. Experiment Runner (FIXED) ---
# This cell will take a long time to run!

def run_all_experiments():
    """
    Main function to run both KFed and FedDP-Init scenarios.
    """
    
    try:
        with open(BASE_CONFIG_PATH, 'r') as f:
            base_config = yaml.safe_load(f)
    except FileNotFoundError:
        print(f"ERROR: Base config file not found at {BASE_CONFIG_PATH}")
        return None, None
    except Exception as e:
        print(f"Error loading base config: {e}")
        return None, None

    # --- Scenario 1: KFed (Non-Private Init) ---
    print("="*50)
    print("STARTING SCENARIO 1: KFed (Non-Private Init)")
    print("="*50)
    kfed_results = []
    temp_config_path = os.path.join(TEMP_CONFIG_DIR, 'temp_kfed_config.yaml') 
    
    for target_eps in EPSILON_TARGET_RANGE:
        print(f"\n--- KFed: Target Epsilon = {target_eps} ---")
        overrides = {
            'initialization_algorithm': 'KFed',
            'fedlloyds_epsilon': target_eps, # Only change this epsilon
            'outer_product_epsilon': 1.0,
            'weighting_epsilon': 1.0,
            'center_init_gaussian_epsilon': 1.0,
            'fedlloyds_num_iterations': 1 # Run 1 Lloyd's iteration
        }
        
        create_temp_config(base_config, overrides, temp_config_path)
        stdout = run_experiment(temp_config_path)
        
        if stdout is not None:
            epsilon, delta, cost, acc = parse_output_and_results(stdout, RESULTS_PKL_PATH)
            kfed_results.append({'target_epsilon': target_eps, 'final_epsilon': epsilon, 'delta': delta, 'cost': cost, 'accuracy': acc})
        
    df_kfed = pd.DataFrame(kfed_results).dropna().sort_values(by='final_epsilon')
    

    # --- Scenario 2: FederatedClusterInitExact (Private Init) --- (FIXED)
    print("="*50)
    print("STARTING SCENARIO 2: FedDP-Init (Private Init)")
    print("="*50)
    feddp_results = []
    temp_config_path = os.path.join(TEMP_CONFIG_DIR, 'temp_feddp_config.yaml')

    for target_eps in EPSILON_TARGET_RANGE:
        print(f"\n--- FedDP-Init: Target Epsilon = {target_eps} ---")
        # *** FIX: Split budget over 3 init steps, set lloyds iterations to 0 ***
        eps_per_step = target_eps / 3.0 
        print(f"    (Setting each of 3 init epsilons to {eps_per_step:.4f})")
        overrides = {
            'initialization_algorithm': 'FederatedClusterInitExact',
            
            # Split budget over the 3 init steps
            'outer_product_epsilon': eps_per_step,
            'weighting_epsilon': eps_per_step,
            'center_init_gaussian_epsilon': eps_per_step,
            
            # Set lloyds epsilon to 1 (it won't be used, but must be > 0)
            'fedlloyds_epsilon': 1.0,
            
            # *** This is the critical fix ***
            'fedlloyds_num_iterations': 0 
        }
        
        create_temp_config(base_config, overrides, temp_config_path)
        stdout = run_experiment(temp_config_path)
        
        if stdout is not None:
            # The final cost will be from the "Initialization" step
            epsilon, delta, cost, acc = parse_output_and_results(stdout, RESULTS_PKL_PATH)
            feddp_results.append({'target_epsilon': target_eps, 'final_epsilon': epsilon, 'delta': delta, 'cost': cost, 'accuracy': acc})

    df_feddp = pd.DataFrame(feddp_results).dropna().sort_values(by='final_epsilon')
    
    # --- Print Final Tables ---
    print("\n" + "="*50)
    print("--- KFed (Non-Private Init) Results Table ---")
    print("="*50)
    print(df_kfed.to_markdown(index=False, floatfmt=".4f"))
    
    print("\n" + "="*50)
    print("--- FedDP-Init (Private Init) Results Table ---")
    print("="*50)
    print(df_feddp.to_markdown(index=False, floatfmt=".4f"))

    return df_kfed, df_feddp

# --- Run the main experiment block ---
df_kfed, df_feddp = run_all_experiments()
# Out:
# ==================================================
# STARTING SCENARIO 1: KFed (Non-Private Init)
# ==================================================
#
# --- KFed: Target Epsilon = 0.25 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.87393488898232
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 324.212646484375
#     Mechanism 1: signal-to-DP-noise ratio             : 17.832568780112947
#     Mechanism 2: Laplace DP noise scale               : 7.999872043728829
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 52.0797, Train Accuracy 0.7809
# Val Cost 52.1595, Val Accuracy 0.7776
#
# Clustering is (0.24423438051108665, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.24423438051108665, Parsed Delta: 1e-06
# Loaded Cost: 52.07969836628121, Accuracy: 0.78087 (from 'Clustering')
#
# --- KFed: Target Epsilon = 0.5 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.87393488898232
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 169.50836181640625
#     Mechanism 1: signal-to-DP-noise ratio             : 34.10772339406493
#     Mechanism 2: Laplace DP noise scale               : 3.9999680127948523
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9886, Train Accuracy 0.7898
# Val Cost 52.0661, Val Accuracy 0.7867
#
# Clustering is (0.4893899061111829, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.4893899061111829, Parsed Delta: 1e-06
# Loaded Cost: 51.98858018560268, Accuracy: 0.78981 (from 'Clustering')
#
# --- KFed: Target Epsilon = 0.75 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.873934888982326
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 115.9820556640625
#     Mechanism 1: signal-to-DP-noise ratio             : 49.848610500240476
#     Mechanism 2: Laplace DP noise scale               : 2.666652435436845
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9686, Train Accuracy 0.7921
# Val Cost 52.0452, Val Accuracy 0.7891
#
# Clustering is (0.7348579036763521, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.7348579036763521, Parsed Delta: 1e-06
# Loaded Cost: 51.968601330068196, Accuracy: 0.79212 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.0 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.873934888982326
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 88.63143920898438
#     Mechanism 1: signal-to-DP-noise ratio             : 65.23130358046807
#     Mechanism 2: Laplace DP noise scale               : 1.9999919924885037
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9608, Train Accuracy 0.7931
# Val Cost 52.0369, Val Accuracy 0.7902
#
# Clustering is (0.9805219619857711, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.9805219619857711, Parsed Delta: 1e-06
# Loaded Cost: 51.960750998432005, Accuracy: 0.79307 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.25 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.873934888982326
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 71.96426391601562
#     Mechanism 1: signal-to-DP-noise ratio             : 80.33910170417765
#     Mechanism 2: Laplace DP noise scale               : 1.5999948838725686
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9568, Train Accuracy 0.7938
# Val Cost 52.0326, Val Accuracy 0.7906
#
# Clustering is (1.226338056312076, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.226338056312076, Parsed Delta: 1e-06
# Loaded Cost: 51.95675354090661, Accuracy: 0.79376 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.5 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.873934888982326
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 60.718536376953125
#     Mechanism 1: signal-to-DP-noise ratio             : 95.21876946970606
#     Mechanism 2: Laplace DP noise scale               : 1.3333297800272703
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9544, Train Accuracy 0.7940
# Val Cost 52.0301, Val Accuracy 0.7910
#
# Clustering is (1.4722775890393438, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.4722775890393438, Parsed Delta: 1e-06
# Loaded Cost: 51.95440679368673, Accuracy: 0.79402 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.75 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.87393488898232
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 52.60734558105469
#     Mechanism 1: signal-to-DP-noise ratio             : 109.89994370476563
#     Mechanism 2: Laplace DP noise scale               : 1.1428545287344605
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9529, Train Accuracy 0.7942
# Val Cost 52.0285, Val Accuracy 0.7912
#
# Clustering is (1.7183111080008233, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.7183111080008233, Parsed Delta: 1e-06
# Loaded Cost: 51.95288631950809, Accuracy: 0.79416 (from 'Clustering')
#
# --- KFed: Target Epsilon = 2.0 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.873934888982326
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 46.47254943847656
#     Mechanism 1: signal-to-DP-noise ratio             : 124.40772859834281
#     Mechanism 2: Laplace DP noise scale               : 0.9999979985877872
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9518, Train Accuracy 0.7943
# Val Cost 52.0273, Val Accuracy 0.7914
#
# Clustering is (1.9644506524561727, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.9644506524561727, Parsed Delta: 1e-06
# Loaded Cost: 51.951829610350345, Accuracy: 0.7943 (from 'Clustering')
#
# --- KFed: Target Epsilon = 2.25 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 100000
#
# Evaluating Initialization...
# Train Cost 53.8739, Train Accuracy 0.6377
# Val Cost 53.9653, Val Accuracy 0.6348
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | kmeans-cost                    : 53.87393488898232
#     Train population | kmeans-accuracy                : 0.64091
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 41.66374206542969
#     Mechanism 1: signal-to-DP-noise ratio             : 138.76680372914157
#     Mechanism 2: Laplace DP noise scale               : 0.8888873097021134
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 1000.0
#     Val population | kmeans-cost                      : 53.96527135685835
#     Val population | kmeans-accuracy                  : 0.63795
#
# Evaluating Clustering...
# Train Cost 51.9511, Train Accuracy 0.7945
# Val Cost 52.0265, Val Accuracy 0.7916
#
# Clustering is (2.210755052373678, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9857, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 2.210755052373678, Parsed Delta: 1e-06
# Loaded Cost: 51.95105773606365, Accuracy: 0.7945 (from 'Clustering')
# ==================================================
# STARTING SCENARIO 2: FedDP-Init (Private Init)
# ==================================================
#
# --- FedDP-Init: Target Epsilon = 0.25 ---
#     (Setting each of 3 init epsilons to 0.0833)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 473.44126740568925
#     Central DP | signal-to-DP-noise ratio on summed stats: 56.53348016463671
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 12.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 902.702179602757
#     Mechanism 1: signal-to-DP-noise ratio             : 6.373751278459197
#     Mechanism 2: Laplace DP noise scale               : 24.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 50.7779, Train Accuracy 0.9762
# Val Cost 50.8155, Val Accuracy 0.9769
#
# Clustering is (0.21072250077856244, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.21072250077856244, Parsed Delta: 1e-06
# Loaded Cost: 50.77794489188761, Accuracy: 0.97625 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 0.5 ---
#     (Setting each of 3 init epsilons to 0.1667)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 247.73002465022844
#     Central DP | signal-to-DP-noise ratio on summed stats: 108.04214199627222
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 6.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 473.44126740568925
#     Mechanism 1: signal-to-DP-noise ratio             : 12.152081313139426
#     Mechanism 2: Laplace DP noise scale               : 12.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 50.1786, Train Accuracy 0.9826
# Val Cost 50.2162, Val Accuracy 0.9829
#
# Clustering is (0.42273238638752525, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.42273238638752525, Parsed Delta: 1e-06
# Loaded Cost: 50.17855446091287, Accuracy: 0.98264 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 0.75 ---
#     (Setting each of 3 init epsilons to 0.2500)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 169.5079524262616
#     Central DP | signal-to-DP-noise ratio on summed stats: 157.89986320342865
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 4.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 324.2003112564916
#     Mechanism 1: signal-to-DP-noise ratio             : 17.746044225341784
#     Mechanism 2: Laplace DP noise scale               : 8.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 50.0567, Train Accuracy 0.9839
# Val Cost 50.0947, Val Accuracy 0.9840
#
# Clustering is (0.6352426205200807, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.6352426205200807, Parsed Delta: 1e-06
# Loaded Cost: 50.056731000187185, Accuracy: 0.98389 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.0 ---
#     (Setting each of 3 init epsilons to 0.3333)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 129.49768888500637
#     Central DP | signal-to-DP-noise ratio on summed stats: 206.6854067470463
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 3.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 247.73002465022844
#     Mechanism 1: signal-to-DP-noise ratio             : 23.224061276943413
#     Mechanism 2: Laplace DP noise scale               : 6.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 50.0119, Train Accuracy 0.9842
# Val Cost 50.0499, Val Accuracy 0.9845
#
# Clustering is (0.8481312975367852, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 0.8481312975367852, Parsed Delta: 1e-06
# Loaded Cost: 50.011871356782, Accuracy: 0.98422 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.25 ---
#     (Setting each of 3 init epsilons to 0.4167)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 105.1017218368639
#     Central DP | signal-to-DP-noise ratio on summed stats: 254.66074230015334
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 2.4
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 201.0475309146864
#     Mechanism 1: signal-to-DP-noise ratio             : 28.616631976085333
#     Mechanism 2: Laplace DP noise scale               : 4.8
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 49.9903, Train Accuracy 0.9845
# Val Cost 50.0284, Val Accuracy 0.9847
#
# Clustering is (1.0612995179625715, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.0612995179625715, Parsed Delta: 1e-06
# Loaded Cost: 49.99031721645027, Accuracy: 0.98447 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.5 ---
#     (Setting each of 3 init epsilons to 0.5000)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 88.63380328797552
#     Central DP | signal-to-DP-noise ratio on summed stats: 301.9760126171987
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 2.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 169.5079524262616
#     Mechanism 1: signal-to-DP-noise ratio             : 33.941135204612465
#     Mechanism 2: Laplace DP noise scale               : 4.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 49.9783, Train Accuracy 0.9846
# Val Cost 50.0164, Val Accuracy 0.9848
#
# Clustering is (1.2747079668706442, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.2747079668706442, Parsed Delta: 1e-06
# Loaded Cost: 49.97828557132206, Accuracy: 0.98457 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.75 ---
#     (Setting each of 3 init epsilons to 0.5833)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 76.75100371712183
#     Central DP | signal-to-DP-noise ratio on summed stats: 348.72876188887057
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 1.7142857142857142
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 146.73425149876718
#     Mechanism 1: signal-to-DP-noise ratio             : 39.20894904586262
#     Mechanism 2: Laplace DP noise scale               : 3.4285714285714284
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 49.9709, Train Accuracy 0.9847
# Val Cost 50.0090, Val Accuracy 0.9849
#
# Clustering is (1.4883520337985676, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.4883520337985676, Parsed Delta: 1e-06
# Loaded Cost: 49.97086328407936, Accuracy: 0.98468 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 2.0 ---
#     (Setting each of 3 init epsilons to 0.6667)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 67.76233680289413
#     Central DP | signal-to-DP-noise ratio on summed stats: 394.9875958064194
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 1.5
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 129.49768888500637
#     Mechanism 1: signal-to-DP-noise ratio             : 44.42781029121049
#     Mechanism 2: Laplace DP noise scale               : 3.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 49.9659, Train Accuracy 0.9847
# Val Cost 50.0041, Val Accuracy 0.9849
#
# Clustering is (1.7021928489475184, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.7021928489475184, Parsed Delta: 1e-06
# Loaded Cost: 49.965947267137494, Accuracy: 0.98471 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 2.25 ---
#     (Setting each of 3 init epsilons to 0.7500)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Fraction of clipped points                        : 0.00095
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 60.71930535503813
#     Central DP | signal-to-DP-noise ratio on summed stats: 440.80350299625377
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 1.3333333333333333
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 100
#     Train population | number of data points          : 1000.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 115.98586499516733
#     Mechanism 1: signal-to-DP-noise ratio             : 49.60340055237118
#     Mechanism 2: Laplace DP noise scale               : 2.6666666666666665
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 49.9625, Train Accuracy 0.9848
# Val Cost 50.0007, Val Accuracy 0.9849
#
# Clustering is (1.9162204360870307, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9476, Train Accuracy 0.9850
# Val Cost 49.9858, Val Accuracy 0.9852
#
#
# Parsed Epsilon (from Clustering): 1.9162204360870307, Parsed Delta: 1e-06
# Loaded Cost: 49.9625175964817, Accuracy: 0.98476 (from 'Clustering')
#
# ==================================================
# --- KFed (Non-Private Init) Results Table ---
# ==================================================
# |   target_epsilon |   final_epsilon |   delta |    cost |   accuracy |
# |-----------------:|----------------:|--------:|--------:|-----------:|
# |           0.2500 |          0.2442 |  0.0000 | 52.0797 |     0.7809 |
# |           0.5000 |          0.4894 |  0.0000 | 51.9886 |     0.7898 |
# |           0.7500 |          0.7349 |  0.0000 | 51.9686 |     0.7921 |
# |           1.0000 |          0.9805 |  0.0000 | 51.9608 |     0.7931 |
# |           1.2500 |          1.2263 |  0.0000 | 51.9568 |     0.7938 |
# |           1.5000 |          1.4723 |  0.0000 | 51.9544 |     0.7940 |
# |           1.7500 |          1.7183 |  0.0000 | 51.9529 |     0.7942 |
# |           2.0000 |          1.9645 |  0.0000 | 51.9518 |     0.7943 |
# |           2.2500 |          2.2108 |  0.0000 | 51.9511 |     0.7945 |
#
# ==================================================
# --- FedDP-Init (Private Init) Results Table ---
# ==================================================
# |   target_epsilon |   final_epsilon |   delta |    cost |   accuracy |
# |-----------------:|----------------:|--------:|--------:|-----------:|
# |           0.2500 |          0.2107 |  0.0000 | 50.7779 |     0.9762 |
# |           0.5000 |          0.4227 |  0.0000 | 50.1786 |     0.9826 |
# |           0.7500 |          0.6352 |  0.0000 | 50.0567 |     0.9839 |
# |           1.0000 |          0.8481 |  0.0000 | 50.0119 |     0.9842 |
# |           1.2500 |          1.0613 |  0.0000 | 49.9903 |     0.9845 |
# |           1.5000 |          1.2747 |  0.0000 | 49.9783 |     0.9846 |
# |           1.7500 |          1.4884 |  0.0000 | 49.9709 |     0.9847 |
# |           2.0000 |          1.7022 |  0.0000 | 49.9659 |     0.9847 |
# |           2.2500 |          1.9162 |  0.0000 | 49.9625 |     0.9848 |

# %% [markdown]
# ---
# ## 4. Results: 2x2 Plot Grid (Separate Plots)
#
# Here are the four separate plots you requested, showing the privacy-utility tradeoff for each scenario and metric independently. We plot against the **final printed epsilon**.

# %%
def plot_2x2_grid(df_kfed, df_feddp):
    """
    Generates the 2x2 plot grid as requested.
    """
    print("\nGenerating 2x2 Plots...")
    if df_kfed.empty and df_feddp.empty:
        print("DataFrames are empty. Skipping 2x2 plot.")
        return

    fig, axes = plt.subplots(2, 2, figsize=(18, 14))
    fig.suptitle('Privacy-Utility Tradeoff Analysis (Gaussian Data-Point)', fontsize=20, y=1.03)
    
    # --- KFed Plots ---
    ax1 = axes[0, 0]
    if not df_kfed.empty:
        ax1.plot(df_kfed['final_epsilon'], df_kfed['cost'], marker='o', linestyle='-', color='blue')
        ax1.set_title('Scenario 1: KFed (Non-Private Init) - Cost vs. Epsilon', fontsize=14)
    else:
        ax1.set_title('Scenario 1: KFed (Non-Private Init) - No Data', fontsize=14)
    ax1.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax1.set_ylabel('K-Means Cost (Train)', fontsize=12)
    ax1.grid(True, linestyle='--', alpha=0.6)
    
    ax2 = axes[0, 1]
    if not df_kfed.empty:
        ax2.plot(df_kfed['final_epsilon'], df_kfed['accuracy'], marker='o', linestyle='-', color='green')
        ax2.set_title('Scenario 1: KFed (Non-Private Init) - Accuracy vs. Epsilon', fontsize=14)
    else:
        ax2.set_title('Scenario 1: KFed (Non-Private Init) - No Data', fontsize=14)
    ax2.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax2.set_ylabel('Clustering Accuracy (Train)', fontsize=12)
    ax2.grid(True, linestyle='--', alpha=0.6)

    # --- FedDP-Init Plots ---
    ax3 = axes[1, 0]
    if not df_feddp.empty:
        ax3.plot(df_feddp['final_epsilon'], df_feddp['cost'], marker='s', linestyle='--', color='red')
        ax3.set_title('Scenario 2: FedDP-Init (Private Init) - Cost vs. Epsilon', fontsize=14)
    else:
        ax3.set_title('Scenario 2: FedDP-Init (Private Init) - No Data', fontsize=14)
    ax3.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax3.set_ylabel('K-Means Cost (Train)', fontsize=12)
    ax3.grid(True, linestyle='--', alpha=0.6)
    
    ax4 = axes[1, 1]
    if not df_feddp.empty:
        ax4.plot(df_feddp['final_epsilon'], df_feddp['accuracy'], marker='s', linestyle='--', color='purple')
        ax4.set_title('Scenario 2: FedDP-Init (Private Init) - Accuracy vs. Epsilon', fontsize=14)
    else:
        ax4.set_title('Scenario 2: FedDP-Init (Private Init) - No Data', fontsize=14)
    ax4.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax4.set_ylabel('Clustering Accuracy (Train)', fontsize=12)
    ax4.grid(True, linestyle='--', alpha=0.6)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

if 'df_kfed' in locals() and 'df_feddp' in locals():
    plot_2x2_grid(df_kfed, df_feddp)
else:
    print("Experiment dataframes not found. Skipping 2x2 plot.")
# Out:
# Generating 2x2 Plots...

# %% [markdown]
# ---
# ## 5. Results: 1x2 Comparative Plots
#
# These plots show both initialization methods on the same axes. This clearly demonstrates the tradeoff and the advantage of using a private initialization (`FedDP-Init`) over a non-private one (`KFed`).

# %%
def plot_comparative_grid(df_kfed, df_feddp):
    """
    Generates a 1x2 comparative plot grid.
    """
    print("\nGenerating 1x2 Comparative Plots...")
    if df_kfed.empty and df_feddp.empty:
        print("DataFrames are empty. Skipping comparative plot.")
        return

    fig, axes = plt.subplots(1, 2, figsize=(20, 8))
    fig.suptitle('Comparative Privacy-Utility Tradeoff (Gaussian Data-Point)', fontsize=20, y=1.03)
    
    # --- Comparative Cost Plot ---
    ax1 = axes[0]
    if not df_kfed.empty:
        ax1.plot(df_kfed['final_epsilon'], df_kfed['cost'], marker='o', linestyle='-', label='KFed (Non-Private Init)')
    if not df_feddp.empty:
        ax1.plot(df_feddp['final_epsilon'], df_feddp['cost'], marker='s', linestyle='--', label='FedDP-Init (Private Init)')
    ax1.set_title('K-Means Cost vs. Epsilon', fontsize=16)
    ax1.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax1.set_ylabel('K-Means Cost (Train)', fontsize=12)
    ax1.legend()
    ax1.grid(True, linestyle='--', alpha=0.6)

    # --- Comparative Accuracy Plot ---
    ax2 = axes[1]
    if not df_kfed.empty:
        ax2.plot(df_kfed['final_epsilon'], df_kfed['accuracy'], marker='o', linestyle='-', label='KFed (Non-Private Init)')
    if not df_feddp.empty:
        ax2.plot(df_feddp['final_epsilon'], df_feddp['accuracy'], marker='s', linestyle='--', label='FedDP-Init (Private Init)')
    ax2.set_title('Clustering Accuracy vs. Epsilon', fontsize=16)
    ax2.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax2.set_ylabel('Clustering Accuracy (Train)', fontsize=12)
    ax2.legend()
    ax2.grid(True, linestyle='--', alpha=0.6)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.93])
    plt.show()

if 'df_kfed' in locals() and 'df_feddp' in locals():
    plot_comparative_grid(df_kfed, df_feddp)
else:
    print("Experiment dataframes not found. Skipping comparative plot.")
# Out:
# Generating 1x2 Comparative Plots...

# %% [markdown]
# ---
# ## 6. Cleanup
#
# This final cell removes all the temporary config files and the results directory created by the experiments.

# %%
def cleanup():
    """Removes all temporary configs and results."""
    print("\n--- Cleaning up temporary files ---")
    temp_files = [
        os.path.join(TEMP_CONFIG_DIR, 'temp_kfed_config.yaml'),
        os.path.join(TEMP_CONFIG_DIR, 'temp_feddp_config.yaml')
    ]
    for f in temp_files:
        if os.path.exists(f):
            os.remove(f)
            print(f"Removed {f}")
            
    # Remove the results directory created by run.py
    if os.path.exists(RESULTS_DIR):
        try:
            shutil.rmtree(RESULTS_DIR)
            print(f"Removed results directory: {RESULTS_DIR}")
        except Exception as e:
            print(f"Error removing results directory {RESULTS_DIR}: {e}")
    else:
        print(f"Results directory not found, no cleanup needed: {RESULTS_DIR}")
        
    print("Cleanup complete.")

cleanup()
# Out:
# --- Cleaning up temporary files ---
# Removed paper_scripts/temp_kfed_config.yaml
# Removed paper_scripts/temp_feddp_config.yaml
# Removed results directory: results/data_point_level/GaussianMixtureUniform
# Cleanup complete.
