# %% [markdown]
# # Privacy-Utility Tradeoff Analysis (Client-Level Privacy)
#
# This notebook runs a series of experiments to compare the privacy-utility tradeoff for two different federated k-means initialization methods on the **Gaussian Client-Level Privacy** scenario.
#
# We will test two scenarios over a range of privacy budgets (epsilon):
#
# 1.  **Scenario 1: `initialization_algorithm: KFed` (Non-Private Init)**
#     * This uses a **non-private** initialization method (`KFed`).
#     * Privacy is **only** applied during the `FederatedLloyds` clustering steps.
#     * We will set `fedlloyds_epsilon` to our target `E` and plot against the final **printed epsilon** for the "Clustering" phase.
#
# 2.  **Scenario 2: `initialization_algorithm: FederatedClusterInit` (Private Init)**
#     * This uses the paper's novel **private** initialization method (`FedDP-Init`).
#     * Following the paper's findings (Table 5), we will set **`fedlloyds_num_iterations: 0`**.
#     * We will split the total target epsilon `E` across the **three** initialization steps (`E/3` each).
#     * We will plot against the final, **printed epsilon** for the "Initialization" phase.
#
# **Metrics:**
# * **Utility (Y-axis):** K-Means Cost (lower is better) and Clustering Accuracy (higher is better).
# * **Privacy (X-axis):** Final Composed Epsilon (lower is better).

# %%
import os
import sys
import subprocess
import yaml
import re
import pickle
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- 1. Setup & Configuration ---

# Add project root to path and change CWD
PROJECT_ROOT = ".."
notebook_dir = os.path.abspath('')
project_root_path = os.path.abspath(os.path.join(notebook_dir, PROJECT_ROOT))

if project_root_path not in sys.path:
    print(f"Adding {project_root_path} to system path.")
    sys.path.insert(0, project_root_path)

if os.getcwd() != project_root_path:
    print(f"Changing CWD from {os.getcwd()} to {project_root_path}")
    os.chdir(project_root_path)
else:
    print(f"Already in correct CWD: {os.getcwd()}")

# --- Global Settings ---
BASE_CONFIG_PATH = 'configs/gaussians_client_privacy.yaml'

# --- !!! --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- ---
# --- TO RUN THE FULL SCRIPT, UNCOMMENT THE "FULL" LINE AND COMMENT THE "TEST" LINE ---
EPSILON_VALUES_TEST = [0.25, 1.0] # Quick test run (2 values)
EPSILON_VALUES_FULL = np.arange(0.25, 2.26, 0.25).tolist() # Full run [0.25, 0.5, ..., 2.25]

# EPSILON_TARGET_RANGE = EPSILON_VALUES_TEST
EPSILON_TARGET_RANGE = EPSILON_VALUES_FULL # <-- UNCOMMENT THIS LINE FOR THE FULL RUN
# --- !!! --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- ---

RESULTS_DIR = 'results/client_level/GaussianMixtureUniform'
RESULTS_PKL_PATH = os.path.join(RESULTS_DIR, 'summary_results.pkl')
TEMP_CONFIG_DIR = 'paper_scripts' # Save temp configs here
SEED = 42

print(f"Base Config: {BASE_CONFIG_PATH}")
print(f"Epsilon Target Range: {EPSILON_TARGET_RANGE}")
print(f"Results Path: {RESULTS_PKL_PATH}")
print(f"CWD: {os.getcwd()}")
# Out:
# Adding /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main to system path.
# Changing CWD from /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main/paper_scripts to /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main
# Base Config: configs/gaussians_client_privacy.yaml
# Epsilon Target Range: [0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0, 2.25]
# Results Path: results/client_level/GaussianMixtureUniform/summary_results.pkl
# CWD: /home/ojmaha/Desktop/IITB/sem7/CS6007/Fed-DP-KMeans-and-MIA-Attack/fed-dp-kmeans-main

# %%
# --- 2. Helper Functions (Unchanged) ---

def create_temp_config(base_config, overrides, path):
    """Creates a temporary YAML config file with specified overrides."""
    config = base_config.copy()
    config.update(overrides)
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, 'w') as f:
        yaml.dump(config, f)
    print(f"Created temp config: {path}")

def run_experiment(config_path):
    """Runs run.py with the given config (from project root) and returns stdout."""
    cmd = ['python', 'run.py', '--args_config', config_path, '--seed', str(SEED)]
    print(f"\n---> Running command: {' '.join(cmd)}")
    
    try:
        result = subprocess.run(cmd, capture_output=True, text=True, check=True, encoding='utf-8')
        print(result.stdout)
        if result.stderr:
            print("--- STDERR ---")
            print(result.stderr)
        return result.stdout
    except subprocess.CalledProcessError as e:
        print(f"--- ERROR running experiment --- (returncode {e.returncode})")
        print("--- STDOUT ---")
        print(e.stdout)
        print("--- STDERR ---")
        print(e.stderr)
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

def parse_output_and_results(stdout, pkl_path):
    """
    Parses the final epsilon/delta from stdout and loads cost/accuracy from the pkl file.
    """
    final_epsilon = np.nan
    final_delta = np.nan
    cost = np.nan
    accuracy = np.nan
    
    try:
        # Pattern to find: "Clustering is (EPSILON, DELTA)-DP"
        pattern_clustering = re.compile(r"Clustering is \(([\d\.]+), ([\de\-\+]+)\)-DP")
        pattern_init = re.compile(r"Initialization is \(([\d\.]+), ([\de\-\+]+)\)-DP")
        
        matches_clustering = pattern_clustering.findall(stdout)
        matches_init = pattern_init.findall(stdout)

        if matches_clustering:
            # If Clustering ran, that's the final, composed cost
            final_epsilon = float(matches_clustering[-1][0])
            final_delta = float(matches_clustering[-1][1])
            print(f"Parsed Epsilon (from Clustering): {final_epsilon}, Parsed Delta: {final_delta}")
        elif matches_init:
            # If only Init ran (e.g., fedlloyds_num_iterations=0), that's the final cost
            final_epsilon = float(matches_init[-1][0])
            final_delta = float(matches_init[-1][1])
            print(f"Parsed Epsilon (from Init): {final_epsilon}, Parsed Delta: {final_delta}")
        else:
            print("Warning: Could not parse epsilon/delta from stdout.")
    except Exception as e:
        print(f"Error parsing epsilon/delta: {e}")

    try:
        with open(pkl_path, 'rb') as f:
            results_dict = pickle.load(f)
        
        final_key = 'Clustering' if 'Clustering' in results_dict else 'Initialization'
        if final_key in results_dict:
            cost = results_dict[final_key].get('Train client cost', np.nan)
            accuracy = results_dict[final_key].get('Train client accuracy', np.nan)
            print(f"Loaded Cost: {cost}, Accuracy: {accuracy} (from '{final_key}')")
        else:
            print(f"Warning: '{final_key}' key not in {pkl_path}.")
            
    except FileNotFoundError:
        print(f"Error: Results file not found at {pkl_path}")
    except Exception as e:
        print(f"Error loading pkl file: {e}")
        
    return final_epsilon, final_delta, cost, accuracy

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# --- 3. Experiment Runner ---
# This cell will take a long time to run!

def run_all_experiments():
    """
    Main function to run both KFed and FedDP-Init scenarios.
    """
    
    try:
        with open(BASE_CONFIG_PATH, 'r') as f:
            base_config = yaml.safe_load(f)
    except FileNotFoundError:
        print(f"ERROR: Base config file not found at {BASE_CONFIG_PATH}")
        return None, None
    except Exception as e:
        print(f"Error loading base config: {e}")
        return None, None

    # --- Scenario 1: KFed (Non-Private Init) ---
    print("="*50)
    print("STARTING SCENARIO 1: KFed (Non-Private Init)")
    print("="*50)
    kfed_results = []
    temp_config_path = os.path.join(TEMP_CONFIG_DIR, 'temp_kfed_config.yaml') 
    
    for target_eps in EPSILON_TARGET_RANGE:
        print(f"\n--- KFed: Target Epsilon = {target_eps} ---")
        overrides = {
            'initialization_algorithm': 'KFed',
            'fedlloyds_epsilon': target_eps, # Only change this epsilon
            'outer_product_epsilon': 1.0,
            'weighting_epsilon': 1.0,
            'center_init_gaussian_epsilon': 1.0,
            # Run 1 Lloyd's iteration to apply the privacy cost
            # The base config defaults to 0, so we MUST override it
            'fedlloyds_num_iterations': 1 
        }
        
        create_temp_config(base_config, overrides, temp_config_path)
        stdout = run_experiment(temp_config_path)
        
        if stdout is not None:
            epsilon, delta, cost, acc = parse_output_and_results(stdout, RESULTS_PKL_PATH)
            kfed_results.append({'target_epsilon': target_eps, 'final_epsilon': epsilon, 'delta': delta, 'cost': cost, 'accuracy': acc})
        
    df_kfed = pd.DataFrame(kfed_results).dropna().sort_values(by='final_epsilon')
    

    # --- Scenario 2: FederatedClusterInit (Private Init) --- 
    print("="*50)
    print("STARTING SCENARIO 2: FedDP-Init (Private Init)")
    print("="*50)
    feddp_results = []
    temp_config_path = os.path.join(TEMP_CONFIG_DIR, 'temp_feddp_config.yaml')

    for target_eps in EPSILON_TARGET_RANGE:
        print(f"\n--- FedDP-Init: Target Epsilon = {target_eps} ---")
        # Split budget over 3 init steps, set lloyds iterations to 0
        # This follows the paper's findings (Table 5) and the base config
        eps_per_step = target_eps / 3.0 
        print(f"    (Setting each of 3 init epsilons to {eps_per_step:.4f})")
        overrides = {
            'initialization_algorithm': 'FederatedClusterInit', # From the client base config
            
            # Split budget over the 3 init steps
            'outer_product_epsilon': eps_per_step,
            'weighting_epsilon': eps_per_step,
            'center_init_gaussian_epsilon': eps_per_step,
            
            # Set lloyds epsilon to 1 (it won't be used, but must be > 0)
            'fedlloyds_epsilon': 1.0,
            
            # Set iterations to 0, as per the base config and paper's findings
            'fedlloyds_num_iterations': 0 
        }
        
        create_temp_config(base_config, overrides, temp_config_path)
        stdout = run_experiment(temp_config_path)
        
        if stdout is not None:
            # The final cost will be from the "Initialization" step
            epsilon, delta, cost, acc = parse_output_and_results(stdout, RESULTS_PKL_PATH)
            feddp_results.append({'target_epsilon': target_eps, 'final_epsilon': epsilon, 'delta': delta, 'cost': cost, 'accuracy': acc})

    df_feddp = pd.DataFrame(feddp_results).dropna().sort_values(by='final_epsilon')
    
    # --- Print Final Tables ---
    print("\n" + "="*50)
    print("--- KFed (Non-Private Init) Results Table ---")
    print("="*50)
    print(df_kfed.to_markdown(index=False, floatfmt=".4f"))
    
    print("\n" + "="*50)
    print("--- FedDP-Init (Private Init) Results Table ---")
    print("="*50)
    print(df_feddp.to_markdown(index=False, floatfmt=".4f"))

    return df_kfed, df_feddp

# --- Run the main experiment block ---
df_kfed, df_feddp = run_all_experiments()
# Out:
# ==================================================
# STARTING SCENARIO 1: KFed (Non-Private Init)
# ==================================================
#
# --- KFed: Target Epsilon = 0.25 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 3536.865234375
#     Mechanism 1: signal-to-DP-noise ratio             : 1.6463847012632153
#     Mechanism 2: Laplace DP noise scale               : 399.9936021864414
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 60.8787, Train Accuracy 0.5013
# Val Cost 60.8485, Val Accuracy 0.5112
#
# Clustering is (0.24423438051116056, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 0.24423438051116056, Parsed Delta: 1e-06
# Loaded Cost: 60.87871422613307, Accuracy: 0.50126 (from 'Clustering')
#
# --- KFed: Target Epsilon = 0.5 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 1849.18212890625
#     Mechanism 1: signal-to-DP-noise ratio             : 3.1489817694425457
#     Mechanism 2: Laplace DP noise scale               : 199.9984006397426
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 54.7091, Train Accuracy 0.6986
# Val Cost 54.6605, Val Accuracy 0.7022
#
# Clustering is (0.4893899061115692, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 0.4893899061115692, Parsed Delta: 1e-06
# Loaded Cost: 54.709141130567126, Accuracy: 0.69858 (from 'Clustering')
#
# --- KFed: Target Epsilon = 0.75 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 1265.2587890625
#     Mechanism 1: signal-to-DP-noise ratio             : 4.6022528060202985
#     Mechanism 2: Laplace DP noise scale               : 133.33262177184224
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 53.2165, Train Accuracy 0.7611
# Val Cost 53.1825, Val Accuracy 0.7582
#
# Clustering is (0.734857903676059, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 0.734857903676059, Parsed Delta: 1e-06
# Loaded Cost: 53.21652769313463, Accuracy: 0.76112 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.0 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 966.888427734375
#     Mechanism 1: signal-to-DP-noise ratio             : 6.022453724003459
#     Mechanism 2: Laplace DP noise scale               : 99.99959962442517
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 52.6256, Train Accuracy 0.7882
# Val Cost 52.6033, Val Accuracy 0.7824
#
# Clustering is (0.980521961986142, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 0.980521961986142, Parsed Delta: 1e-06
# Loaded Cost: 52.625557053752324, Accuracy: 0.78821 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.25 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 785.064697265625
#     Mechanism 1: signal-to-DP-noise ratio             : 7.417275076291607
#     Mechanism 2: Laplace DP noise scale               : 79.99974419362843
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 52.3264, Train Accuracy 0.8035
# Val Cost 52.3107, Val Accuracy 0.8000
#
# Clustering is (1.226338056312396, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 1.226338056312396, Parsed Delta: 1e-06
# Loaded Cost: 52.32638116425248, Accuracy: 0.80349 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.5 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 662.384033203125
#     Mechanism 1: signal-to-DP-noise ratio             : 8.791034385514932
#     Mechanism 2: Laplace DP noise scale               : 66.66648900136352
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 52.1533, Train Accuracy 0.8126
# Val Cost 52.1404, Val Accuracy 0.8094
#
# Clustering is (1.4722775890396953, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 1.4722775890396953, Parsed Delta: 1e-06
# Loaded Cost: 52.15334759501568, Accuracy: 0.81257 (from 'Clustering')
#
# --- KFed: Target Epsilon = 1.75 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 573.8983154296875
#     Mechanism 1: signal-to-DP-noise ratio             : 10.146467859807055
#     Mechanism 2: Laplace DP noise scale               : 57.142726436723024
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 52.0446, Train Accuracy 0.8194
# Val Cost 52.0323, Val Accuracy 0.8164
#
# Clustering is (1.7183111080017006, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 1.7183111080017006, Parsed Delta: 1e-06
# Loaded Cost: 52.04459710415798, Accuracy: 0.81936 (from 'Clustering')
#
# --- KFed: Target Epsilon = 2.0 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 506.9732666015625
#     Mechanism 1: signal-to-DP-noise ratio             : 11.485893233264203
#     Mechanism 2: Laplace DP noise scale               : 49.99989992938936
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 51.9720, Train Accuracy 0.8236
# Val Cost 51.9601, Val Accuracy 0.8206
#
# Clustering is (1.9644506524538372, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 1.9644506524538372, Parsed Delta: 1e-06
# Loaded Cost: 51.97195794649266, Accuracy: 0.82363 (from 'Clustering')
#
# --- KFed: Target Epsilon = 2.25 ---
# Created temp config: paper_scripts/temp_kfed_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_kfed_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
# Running user 1000.
# Running user 2000.
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | total weight                   : 1.0
#     Number of parameters                              : 2000000
#
# Evaluating Initialization...
# Train Cost 53.1035, Train Accuracy 0.6843
# Val Cost 53.1052, Val Accuracy 0.6968
#
# Initialization is (0, 1e-06)-DP
#
#
# #########
# Running Clustering
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Train population | kmeans-cost                    : 53.10353291145103
#     Train population | kmeans-accuracy                : 0.7285
#     Mechanism 1: l2 norm bound                        : 120.0
#     Mechanism 1: fraction of clipped norms            : 0.036
#     Mechanism 1: norm before clipping                 : 111.56927505874634
#     Mechanism 2: l1 norm bound                        : 50.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 454.5135498046875
#     Mechanism 1: signal-to-DP-noise ratio             : 12.811589038009977
#     Mechanism 2: Laplace DP noise scale               : 44.44436548510566
#     Number of parameters                              : 1010
#     Val population | number of devices                : 100
#     Val population | number of data points            : 50.0
#     Val population | kmeans-cost                      : 53.10524405670647
#     Val population | kmeans-accuracy                  : 0.7398
#
# Evaluating Clustering...
# Train Cost 51.9212, Train Accuracy 0.8268
# Val Cost 51.9096, Val Accuracy 0.8220
#
# Clustering is (2.210755052373656, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 50.7184, Train Accuracy 0.8821
# Val Cost 50.7968, Val Accuracy 0.8872
#
#
# Parsed Epsilon (from Clustering): 2.210755052373656, Parsed Delta: 1e-06
# Loaded Cost: 51.921171691520385, Accuracy: 0.82676 (from 'Clustering')
# ==================================================
# STARTING SCENARIO 2: FedDP-Init (Private Init)
# ==================================================
#
# --- FedDP-Init: Target Epsilon = 0.25 ---
#     (Setting each of 3 init epsilons to 0.0833)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 64560.17282804853
#     Central DP | signal-to-DP-noise ratio on summed stats: 0.41332998087029127
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 12.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.231
#     Mechanism 1: norm before clipping                 : 19.814331728611805
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 8.836
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 903.8424195926794
#     Mechanism 1: signal-to-DP-noise ratio             : 1.0395640660530585
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 71.1143, Train Accuracy 0.2444
# Val Cost 71.1771, Val Accuracy 0.2456
#
# Clustering is (0.3927212323496734, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 0.3927212323496734, Parsed Delta: 1e-06
# Loaded Cost: 71.11432088959054, Accuracy: 0.24435 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 0.5 ---
#     (Setting each of 3 init epsilons to 0.1667)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 33781.36699775842
#     Central DP | signal-to-DP-noise ratio on summed stats: 0.789922296565757
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 6.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.2925
#     Mechanism 1: norm before clipping                 : 20.389564215522952
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.695
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 472.93913796861796
#     Mechanism 1: signal-to-DP-noise ratio             : 2.1382200225348944
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 58.0706, Train Accuracy 0.3969
# Val Cost 58.0921, Val Accuracy 0.4024
#
# Clustering is (0.5870835169834716, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 0.5870835169834716, Parsed Delta: 1e-06
# Loaded Cost: 58.07055462852125, Accuracy: 0.39687 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 0.75 ---
#     (Setting each of 3 init epsilons to 0.2500)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 23114.72078539931
#     Central DP | signal-to-DP-noise ratio on summed stats: 1.1544441850604434
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 4.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.4045
#     Mechanism 1: norm before clipping                 : 20.808307315191254
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.883
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 323.6060909955903
#     Mechanism 1: signal-to-DP-noise ratio             : 3.2373369032245054
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 55.6284, Train Accuracy 0.5389
# Val Cost 55.6278, Val Accuracy 0.5426
#
# Clustering is (0.7821489445791787, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 0.7821489445791787, Parsed Delta: 1e-06
# Loaded Cost: 55.62842733316278, Accuracy: 0.53885 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.0 ---
#     (Setting each of 3 init epsilons to 0.3333)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 17658.77575704632
#     Central DP | signal-to-DP-noise ratio on summed stats: 1.5111271226915102
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 3.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.3315
#     Mechanism 1: norm before clipping                 : 20.620818300365986
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.8395
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 247.22286059864848
#     Mechanism 1: signal-to-DP-noise ratio             : 4.1928175307924755
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 54.6525, Train Accuracy 0.5610
# Val Cost 54.7295, Val Accuracy 0.5684
#
# Clustering is (0.9777463077392943, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 0.9777463077392943, Parsed Delta: 1e-06
# Loaded Cost: 54.652542624435526, Accuracy: 0.56104 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.25 ---
#     (Setting each of 3 init epsilons to 0.4167)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 14332.052977754169
#     Central DP | signal-to-DP-noise ratio on summed stats: 1.861886433256925
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 2.4
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.3505
#     Mechanism 1: norm before clipping                 : 20.628031988977096
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.794
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 200.64874168855837
#     Mechanism 1: signal-to-DP-noise ratio             : 5.174403227420196
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 53.7483, Train Accuracy 0.6749
# Val Cost 53.7559, Val Accuracy 0.6798
#
# Clustering is (1.1737788095361295, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 1.1737788095361295, Parsed Delta: 1e-06
# Loaded Cost: 53.74833180997068, Accuracy: 0.67488 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.5 ---
#     (Setting each of 3 init epsilons to 0.5000)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 12086.42772108757
#     Central DP | signal-to-DP-noise ratio on summed stats: 2.207819846838818
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 2.0
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.3425
#     Mechanism 1: norm before clipping                 : 20.55426265778063
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.7205
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 169.20998809522598
#     Mechanism 1: signal-to-DP-noise ratio             : 6.162866343686521
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 53.0043, Train Accuracy 0.7663
# Val Cost 53.0144, Val Accuracy 0.7786
#
# Clustering is (1.37020196608317, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 1.37020196608317, Parsed Delta: 1e-06
# Loaded Cost: 53.00432899836735, Accuracy: 0.76627 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 1.75 ---
#     (Setting each of 3 init epsilons to 0.5833)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 10466.045961425703
#     Central DP | signal-to-DP-noise ratio on summed stats: 2.5496405326663565
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 1.7142857142857142
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.346
#     Mechanism 1: norm before clipping                 : 20.773337367564135
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.921
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 146.52464345995986
#     Mechanism 1: signal-to-DP-noise ratio             : 7.331441853347775
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 52.0891, Train Accuracy 0.8558
# Val Cost 52.1194, Val Accuracy 0.8568
#
# Clustering is (1.5669899565507557, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 1.5669899565507557, Parsed Delta: 1e-06
# Loaded Cost: 52.089129202414554, Accuracy: 0.85579 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 2.0 ---
#     (Setting each of 3 init epsilons to 0.6667)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 9240.318654940109
#     Central DP | signal-to-DP-noise ratio on summed stats: 2.887850083582746
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 1.5
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.4945
#     Mechanism 1: norm before clipping                 : 20.957476957696542
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.83
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 129.3644611691615
#     Mechanism 1: signal-to-DP-noise ratio             : 8.218431520680259
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 52.1833, Train Accuracy 0.7727
# Val Cost 52.2646, Val Accuracy 0.7812
#
# Clustering is (1.7641173804546468, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 1.7641173804546468, Parsed Delta: 1e-06
# Loaded Cost: 52.18326160589956, Accuracy: 0.77269 (from 'Clustering')
#
# --- FedDP-Init: Target Epsilon = 2.25 ---
#     (Setting each of 3 init epsilons to 0.7500)
# Created temp config: paper_scripts/temp_feddp_config.yaml
#
# ---> Running command: python run.py --args_config paper_scripts/temp_feddp_config.yaml --seed 42
# Final Server Dataset Size: 300 samples
#
# #########
# Running Outer Product Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l2 norm bound                        : 1500.0
#     Central DP | fraction of clipped norms            : 0.1675
#     Central DP | norm before clipping                 : 1450.6398331298828
#     Train population | total weight                   : 1.0
#     Central DP | DP noise std. dev. on summed stats   : 8279.905275687019
#     Central DP | signal-to-DP-noise ratio on summed stats: 3.2228212897986155
#     Number of parameters                              : 10000
#
# #########
# Running Point Weighting Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Central DP | l1 norm bound                        : 1.0
#     Central DP | fraction of clipped norms            : 1.0
#     Central DP | norm before clipping                 : 50.0
#     Train population | total weight                   : 1.0
#     Central DP | Laplace DP noise scale on summed stats: 1.3333333333333333
#     Number of parameters                              : 300
#
# #########
# Running Center Computation
# #########
#
# Metrics at iteration 0 ():
#     Train population | number of devices              : 2000
#     Train population | number of data points          : 50.0
#     Mechanism 1: l2 norm bound                        : 21.0
#     Mechanism 1: fraction of clipped norms            : 0.456
#     Mechanism 1: norm before clipping                 : 20.954424924687416
#     Mechanism 2: l1 norm bound                        : 10.0
#     Mechanism 2: fraction of clipped norms            : 0.0
#     Mechanism 2: norm before clipping                 : 9.9305
#     Train population | total weight                   : 1.0
#     Mechanism 1: DP noise std. dev.                   : 115.91867385961825
#     Mechanism 1: signal-to-DP-noise ratio             : 9.389511318441164
#     Mechanism 2: Laplace DP noise scale               : 50.0
#     Number of parameters                              : 1010
#
# Evaluating Clustering...
# Train Cost 51.5713, Train Accuracy 0.8157
# Val Cost 51.6123, Val Accuracy 0.8190
#
# Clustering is (1.9615684130420157, 1e-06)-DP
#
#
# Evaluating Optimal...
# Train Cost 49.9483, Train Accuracy 0.9848
# Val Cost 50.0108, Val Accuracy 0.9846
#
#
# Parsed Epsilon (from Clustering): 1.9615684130420157, Parsed Delta: 1e-06
# Loaded Cost: 51.57134385522736, Accuracy: 0.81566 (from 'Clustering')
#
# ==================================================
# --- KFed (Non-Private Init) Results Table ---
# ==================================================
# |   target_epsilon |   final_epsilon |   delta |    cost |   accuracy |
# |-----------------:|----------------:|--------:|--------:|-----------:|
# |           0.2500 |          0.2442 |  0.0000 | 60.8787 |     0.5013 |
# |           0.5000 |          0.4894 |  0.0000 | 54.7091 |     0.6986 |
# |           0.7500 |          0.7349 |  0.0000 | 53.2165 |     0.7611 |
# |           1.0000 |          0.9805 |  0.0000 | 52.6256 |     0.7882 |
# |           1.2500 |          1.2263 |  0.0000 | 52.3264 |     0.8035 |
# |           1.5000 |          1.4723 |  0.0000 | 52.1533 |     0.8126 |
# |           1.7500 |          1.7183 |  0.0000 | 52.0446 |     0.8194 |
# |           2.0000 |          1.9645 |  0.0000 | 51.9720 |     0.8236 |
# |           2.2500 |          2.2108 |  0.0000 | 51.9212 |     0.8268 |
#
# ==================================================
# --- FedDP-Init (Private Init) Results Table ---
# ==================================================
# |   target_epsilon |   final_epsilon |   delta |    cost |   accuracy |
# |-----------------:|----------------:|--------:|--------:|-----------:|
# |           0.2500 |          0.3927 |  0.0000 | 71.1143 |     0.2444 |
# |           0.5000 |          0.5871 |  0.0000 | 58.0706 |     0.3969 |
# |           0.7500 |          0.7821 |  0.0000 | 55.6284 |     0.5389 |
# |           1.0000 |          0.9777 |  0.0000 | 54.6525 |     0.5610 |
# |           1.2500 |          1.1738 |  0.0000 | 53.7483 |     0.6749 |
# |           1.5000 |          1.3702 |  0.0000 | 53.0043 |     0.7663 |
# |           1.7500 |          1.5670 |  0.0000 | 52.0891 |     0.8558 |
# |           2.0000 |          1.7641 |  0.0000 | 52.1833 |     0.7727 |
# |           2.2500 |          1.9616 |  0.0000 | 51.5713 |     0.8157 |

# %% [markdown]
# ---
# ## 4. Results: 2x2 Plot Grid (Separate Plots)
#
# Here are the four separate plots you requested, showing the privacy-utility tradeoff for each scenario and metric independently. We plot against the **final printed epsilon**.

# %%
def plot_2x2_grid(df_kfed, df_feddp):
    """
    Generates the 2x2 plot grid as requested.
    """
    print("\nGenerating 2x2 Plots...")
    if df_kfed.empty and df_feddp.empty:
        print("DataFrames are empty. Skipping 2x2 plot.")
        return

    fig, axes = plt.subplots(2, 2, figsize=(18, 14))
    fig.suptitle('Privacy-Utility Tradeoff Analysis (Gaussian Client-Level)', fontsize=20, y=1.03)
    
    # --- KFed Plots ---
    ax1 = axes[0, 0]
    if not df_kfed.empty:
        ax1.plot(df_kfed['final_epsilon'], df_kfed['cost'], marker='o', linestyle='-', color='blue')
        ax1.set_title('Scenario 1: KFed (Non-Private Init) - Cost vs. Epsilon', fontsize=14)
    else:
        ax1.set_title('Scenario 1: KFed (Non-Private Init) - No Data', fontsize=14)
    ax1.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax1.set_ylabel('K-Means Cost (Train)', fontsize=12)
    ax1.grid(True, linestyle='--', alpha=0.6)
    
    ax2 = axes[0, 1]
    if not df_kfed.empty:
        ax2.plot(df_kfed['final_epsilon'], df_kfed['accuracy'], marker='o', linestyle='-', color='green')
        ax2.set_title('Scenario 1: KFed (Non-Private Init) - Accuracy vs. Epsilon', fontsize=14)
    else:
        ax2.set_title('Scenario 1: KFed (Non-Private Init) - No Data', fontsize=14)
    ax2.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax2.set_ylabel('Clustering Accuracy (Train)', fontsize=12)
    ax2.grid(True, linestyle='--', alpha=0.6)

    # --- FedDP-Init Plots ---
    ax3 = axes[1, 0]
    if not df_feddp.empty:
        ax3.plot(df_feddp['final_epsilon'], df_feddp['cost'], marker='s', linestyle='--', color='red')
        ax3.set_title('Scenario 2: FedDP-Init (Private Init) - Cost vs. Epsilon', fontsize=14)
    else:
        ax3.set_title('Scenario 2: FedDP-Init (Private Init) - No Data', fontsize=14)
    ax3.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax3.set_ylabel('K-Means Cost (Train)', fontsize=12)
    ax3.grid(True, linestyle='--', alpha=0.6)
    
    ax4 = axes[1, 1]
    if not df_feddp.empty:
        ax4.plot(df_feddp['final_epsilon'], df_feddp['accuracy'], marker='s', linestyle='--', color='purple')
        ax4.set_title('Scenario 2: FedDP-Init (Private Init) - Accuracy vs. Epsilon', fontsize=14)
    else:
        ax4.set_title('Scenario 2: FedDP-Init (Private Init) - No Data', fontsize=14)
    ax4.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax4.set_ylabel('Clustering Accuracy (Train)', fontsize=12)
    ax4.grid(True, linestyle='--', alpha=0.6)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

if 'df_kfed' in locals() and 'df_feddp' in locals():
    plot_2x2_grid(df_kfed, df_feddp)
else:
    print("Experiment dataframes not found. Skipping 2x2 plot.")
# Out:
# Generating 2x2 Plots...

# %% [markdown]
# ---
# ## 5. Results: 1x2 Comparative Plots
#
# These plots show both initialization methods on the same axes. This clearly demonstrates the tradeoff and the advantage of using a private initialization (`FedDP-Init`) over a non-private one (`KFed`).

# %%
def plot_comparative_grid(df_kfed, df_feddp):
    """
    Generates a 1x2 comparative plot grid.
    """
    print("\nGenerating 1x2 Comparative Plots...")
    if df_kfed.empty and df_feddp.empty:
        print("DataFrames are empty. Skipping comparative plot.")
        return

    fig, axes = plt.subplots(1, 2, figsize=(20, 8))
    fig.suptitle('Comparative Privacy-Utility Tradeoff (Gaussian Client-Level)', fontsize=20, y=1.03)
    
    # --- Comparative Cost Plot ---
    ax1 = axes[0]
    if not df_kfed.empty:
        ax1.plot(df_kfed['final_epsilon'], df_kfed['cost'], marker='o', linestyle='-', label='KFed (Non-Private Init)')
    if not df_feddp.empty:
        ax1.plot(df_feddp['final_epsilon'], df_feddp['cost'], marker='s', linestyle='--', label='FedDP-Init (Private Init)')
    ax1.set_title('K-Means Cost vs. Epsilon', fontsize=16)
    ax1.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax1.set_ylabel('K-Means Cost (Train)', fontsize=12)
    ax1.legend()
    ax1.grid(True, linestyle='--', alpha=0.6)

    # --- Comparative Accuracy Plot ---
    ax2 = axes[1]
    if not df_kfed.empty:
        ax2.plot(df_kfed['final_epsilon'], df_kfed['accuracy'], marker='o', linestyle='-', label='KFed (Non-Private Init)')
    if not df_feddp.empty:
        ax2.plot(df_feddp['final_epsilon'], df_feddp['accuracy'], marker='s', linestyle='--', label='FedDP-Init (Private Init)')
    ax2.set_title('Clustering Accuracy vs. Epsilon', fontsize=16)
    ax2.set_xlabel('Final Composed Epsilon (Delta = 1e-06)', fontsize=12)
    ax2.set_ylabel('Clustering Accuracy (Train)', fontsize=12)
    ax2.legend()
    ax2.grid(True, linestyle='--', alpha=0.6)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.93])
    plt.show()

if 'df_kfed' in locals() and 'df_feddp' in locals():
    plot_comparative_grid(df_kfed, df_feddp)
else:
    print("Experiment dataframes not found. Skipping comparative plot.")
# Out:
# Generating 1x2 Comparative Plots...

# %% [markdown]
# ---
# ## 6. Cleanup
#
# This final cell removes all the temporary config files and the results directory created by the experiments.

# %%
def cleanup():
    """Removes all temporary configs and results."""
    print("\n--- Cleaning up temporary files ---")
    temp_files = [
        os.path.join(TEMP_CONFIG_DIR, 'temp_kfed_config.yaml'),
        os.path.join(TEMP_CONFIG_DIR, 'temp_feddp_config.yaml')
    ]
    for f in temp_files:
        if os.path.exists(f):
            os.remove(f)
            print(f"Removed {f}")
            
    # Remove the results directory created by run.py
    if os.path.exists(RESULTS_DIR):
        try:
            shutil.rmtree(RESULTS_DIR)
            print(f"Removed results directory: {RESULTS_DIR}")
        except Exception as e:
            print(f"Error removing results directory {RESULTS_DIR}: {e}")
    else:
        print(f"Results directory not found, no cleanup needed: {RESULTS_DIR}")
        
    print("Cleanup complete.")

cleanup()
# Out:
# --- Cleaning up temporary files ---
# Removed paper_scripts/temp_kfed_config.yaml
# Removed paper_scripts/temp_feddp_config.yaml
# Removed results directory: results/client_level/GaussianMixtureUniform
# Cleanup complete.
